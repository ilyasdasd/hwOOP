# %%
from statistics import mean

class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Lecturer) and course in self.courses_in_progress and course in lecturer.courses_attached:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        avg_grades = self.compute_avg_grade()

        return f'{res} \nСредняя оценка за дз: {avg_grades} \nКурсы в процессе изучения: {self.courses_in_progress} \nЗавершенные курсы: {self.finished_courses}'

    def __lt__(self, other):
        if not isinstance(other, Student): 
            print('не студент')
            return
        return self.compute_avg_grade() < other.compute_avg_grade()
    
    def __eq__(self, other):
        if not isinstance(other, Student): 
            print('не студент')
            return
        return self.compute_avg_grade() == other.compute_avg_grade()
    def compute_avg_grade(self):
        sum_grades = 0
        n_grades = 0
        for course in self.grades:
            sum_grades += sum(self.grades[course])
            n_grades += len(self.grades[course])
        if n_grades == 0:
            return
        return round(sum_grades / n_grades, 3)


    


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []
        
    


class Lecturer(Mentor):
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        # self.grades = {7, 8 , 10}
        self.grades = {}

    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        
        return f'{res}\nСредняя оценка за лекции {round(self.compute_avg_grade(), 3)}'

    def __lt__(self, other):
        if not isinstance(other, Lecturer): 
            print('не лектор')
            return
        return self.compute_avg_grade() < other.compute_avg_grade()
    
    def __eq__(self, other):
        if not isinstance(other, Lecturer): 
            print('не лектор')
            return
        return self.compute_avg_grade() == other.compute_avg_grade()
        
    def compute_avg_grade(self):
        sum_grades = 0
        n_grades = 0
        for course in self.grades:
            sum_grades += sum(self.grades[course])
            n_grades += len(self.grades[course])
        if n_grades == 0:
            return
        return round(sum_grades / n_grades, 3)

    
    


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'
        
    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        return res
        

    


    

def grade(student_list, course):
    n_grades = 0
    sum_grades = 0
    for student in student_list:
        if course in student.grades:
            sum_grades += sum(student.grades[course])
            n_grades += len(student.grades[course])
    if n_grades == 0:
        return
    return round(sum_grades / n_grades, 3)



        

'''
best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python']
 
cool_mentor = Reviewer('Some', 'Buddy')
cool_mentor.courses_attached += ['Python']
 
# cool_mentor.rate_hw(best_student, 'Python', 10)
# cool_mentor.rate_hw(best_student, 'Python', 10)
# cool_mentor.rate_hw(best_student, 'Python', 10)

some_lecturer = Lecturer('Some', 'Buddy', {10})
some_student = Student('Ruoy', 'Eman', 'male')
some_lecturer1 = Lecturer('name' , 'surname', {19})
# all_students_avgGrade = Student()

print(cool_mentor)
print(some_lecturer)
print(some_student)
print(some_lecturer == some_lecturer1)


'''
# print(best_student.grades)
# Out:
# "\nbest_student = Student('Ruoy', 'Eman', 'your_gender')\nbest_student.courses_in_progress += ['Python']\n \ncool_mentor = Reviewer('Some', 'Buddy')\ncool_mentor.courses_attached += ['Python']\n \n# cool_mentor.rate_hw(best_student, 'Python', 10)\n# cool_mentor.rate_hw(best_student, 'Python', 10)\n# cool_mentor.rate_hw(best_student, 'Python', 10)\n\nsome_lecturer = Lecturer('Some', 'Buddy', {10})\nsome_student = Student('Ruoy', 'Eman', 'male')\nsome_lecturer1 = Lecturer('name' , 'surname', {19})\n# all_students_avgGrade = Student()\n\nprint(cool_mentor)\nprint(some_lecturer)\nprint(some_student)\nprint(some_lecturer == some_lecturer1)\n\n\n"

# %%
student1 = Student('some', 'buddy', 'male')
student1.courses_in_progress = ['asd', 'tr']

student2 = Student('ivan', 'ivan', 'male')
student2.courses_in_progress = ['asd']

rew = Reviewer('any','body')
rew1 = Reviewer('nadya', 'assdd')
rew1.courses_attached = ['tr']
rew.courses_attached = ['asd']
rew.rate_hw(student1, 'asd', 123)
rew.rate_hw(student2, 'asd', 33)
print(student1 < student2)

lector12 = Lecturer('asd', 'dsa')
lector12.courses_attached = ['tr']
lector13 = Lecturer('vasya', 'dsa')
lector13.courses_attached = ['ass']

print(grade([student1, student2], 'asd'))


student1.rate_lecturer(lector12, 'tr', 12)

print(lector12.grades)
print(lector12)
print(grade([lector12, lector13], 'tr'))
# Out:
# False
# 78.0
# {'tr': [12]}
# Имя: asd
# Фамилия: dsa
# Средняя оценка за лекции 12.0
# 12.0

# %%
lector12.courses_attached
# Out:
# ['tr']
