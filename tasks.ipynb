# %%
from statistics import mean

class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {4, 6}

    def rate_lecturer(self, lecturer, course, grade):
        if isinstance(lecturer, Student) and course in self.courses_attached and course in lecturer.courses_in_progress:
            if course in lecturer.grades:
                lecturer.grades[course] += [grade]
            else:
                lecturer.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        avg_grades = round(mean(self.grades))

        return f'{res} \nСредняя оценка за дз: {avg_grades} \nКурсы в процессе изучения: {self.courses_in_progress} \nЗавершенные курсы: {self.finished_courses}'


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []
        
    


class Lecturer(Mentor):
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.grades = {7, 8 , 10}

    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        
        return f'{res}\nСредняя оценка за лекции {round(mean(self.grades), 3)}'


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'
        
    def __str__(self):
        res = f'Имя: {self.name} \nФамилия: {self.surname}'
        return res
        
class Comparing(Lecturer, Student):
    def compare(self, grade)
    



best_student = Student('Ruoy', 'Eman', 'your_gender')
best_student.courses_in_progress += ['Python']
 
cool_mentor = Reviewer('Some', 'Buddy')
cool_mentor.courses_attached += ['Python']
 
# cool_mentor.rate_hw(best_student, 'Python', 10)
# cool_mentor.rate_hw(best_student, 'Python', 10)
# cool_mentor.rate_hw(best_student, 'Python', 10)

some_lecturer = Lecturer('Some', 'Buddy')
some_student = Student('Ruoy', 'Eman', 'male')


print(cool_mentor)
print(some_lecturer)
print(some_student)




# print(best_student.grades)
# Out:
# Имя: Some
# Фамилия: Buddy
# Имя: Some
# Фамилия: Buddy
# Средняя оценка за лекции 8.333
# Имя: Ruoy
# Фамилия: Eman
# Средняя оценка за дз: 5
# Курсы в процессе изучения: []
# Завершенные курсы: []
